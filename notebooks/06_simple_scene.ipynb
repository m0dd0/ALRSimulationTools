# %%
from matplotlib import pyplot as plt
from scipy.spatial.transform import Rotation as R

from alr_sim.sims.SimFactory import SimRepository
from alr_sim.sims.universal_sim.PrimitiveObjects import Box
from alr_sim.core import Scene
from alr_sim.sims.mj_beta import MjCamera
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from matplotlib import pyplot as plt
#       2 from scipy.spatial.transform import Rotation as R
# ----> 4 from alr_sim.sims.SimFactory import SimRepository
#       5 from alr_sim.sims.universal_sim.PrimitiveObjects import Box
#       6 from alr_sim.core import Scene
#
# File ~/Documents/SimulationFramework/alr_sim/sims/__init__.py:2
#       1 from .mj_beta import *
# ----> 2 from .mujoco import *
#       3 from .pybullet import *
#       4 from .sl import *
#
# File ~/Documents/SimulationFramework/alr_sim/sims/mujoco/__init__.py:4
#       1 import logging
#       3 try:
# ----> 4     import mujoco_py
#       6     if mujoco_py.__file__ is None:
#       7         raise ImportError(
#       8             f"mujoco_py has been uninstalled but the generated mujoco files still exist in {list(mujoco_py.__path__)}"
#       9         )
#
# File ~/mambaforge/envs/benchmark_grconvnet/lib/python3.9/site-packages/mujoco_py/__init__.py:2
#       1 #!/usr/bin/env python
# ----> 2 from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#       3 from mujoco_py.generated import const
#       4 from mujoco_py.mjrenderpool import MjRenderPool
#
# File ~/mambaforge/envs/benchmark_grconvnet/lib/python3.9/site-packages/mujoco_py/builder.py:504
#     500     return module.lib.__fun
#     503 mujoco_path = discover_mujoco()
# --> 504 cymj = load_cython_ext(mujoco_path)
#     507 # Trick to expose all mj* functions from mujoco in mujoco_py.*
#     508 class dict2(object):
#
# File ~/mambaforge/envs/benchmark_grconvnet/lib/python3.9/site-packages/mujoco_py/builder.py:74, in load_cython_ext(mujoco_path)
#      72     Builder = MacExtensionBuilder
#      73 elif sys.platform == 'linux':
# ---> 74     _ensure_set_env_var("LD_LIBRARY_PATH", lib_path)
#      75     if os.getenv('MUJOCO_PY_FORCE_CPU') is None and get_nvidia_lib_dir() is not None:
#      76         _ensure_set_env_var("LD_LIBRARY_PATH", get_nvidia_lib_dir())
#
# File ~/mambaforge/envs/benchmark_grconvnet/lib/python3.9/site-packages/mujoco_py/builder.py:120, in _ensure_set_env_var(var_name, lib_path)
#     118 paths = [os.path.abspath(path) for path in paths]
#     119 if lib_path not in paths:
# --> 120     raise Exception("\nMissing path to your environment variable. \n"
#     121                     "Current values %s=%s\n"
#     122                     "Please add following line to .bashrc:\n"
#     123                     "export %s=$%s:%s" % (var_name, os.environ.get(var_name, ""),
#     124                                           var_name, var_name, lib_path))
#
# Exception:
# Missing path to your environment variable.
# Current values LD_LIBRARY_PATH=
# Please add following line to .bashrc:
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/i53/student/m_hesche/.mujoco/mujoco210/bin

# %%
box1 = Box(
    name="box1",
    init_pos=[0.5, -0.2, 0.0],
    init_quat=[0, 1, 0, 0],
    rgba=[0.1, 0.25, 0.3, 1],
)
object_list = [box1]

# Generate the chosen Scene and Agent
sim_factory = SimRepository.get_factory("mj_beta")
scene = sim_factory.create_scene(
    object_list=object_list, dt=0.0002, render=Scene.RenderMode.BLIND
)
agent = sim_factory.create_robot(scene, dt=0.0002)

cam = MjCamera(
    "my_cam",
    init_pos=(1.2, 0, 1),
    init_quat=R.from_euler("zyx", (90, 50, 0), degrees=True)
    .as_quat()[[3, 0, 1, 2]]
    .tolist(),
)
scene.add_object(cam)
# cam.set_cam_params(height=cam_height, width=cam_width)

# start simulation
scene.start()

agent.wait(1)
# # go to start position
# agent.gotoCartPositionAndQuat(robot_pos, robot_quat, duration=move_duration)

# %%
# get camera data
rgb_img, depth_img_denormalized = cam.get_image(denormalize_depth=True) # default
rgb_img, depth_img_normalized = cam.get_image(denormalize_depth=False)

# %%
plt.imshow(rgb_img)
